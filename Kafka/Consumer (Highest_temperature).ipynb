# %% [markdown]
# ****
# ### >> Let consumer Decide how many result want to show
# ****

# %%
from kafka import KafkaAdminClient, KafkaConsumer, KafkaProducer
import sys
import json
from json import loads
from pykafka import KafkaClient 
import logging
logger = logging.getLogger('kafka')
logger.setLevel(logging.WARN)

client = KafkaClient(hosts="localhost:9092") #initialize KafkaClient

### Setting up the Python consumer
topicName = client.topics['Highest_air_temp1']
consumer = topicName.get_simple_consumer()


### Reading the message from consumer
input_text = []

user_input = int(input ("Please enter how many result to show: "))

 #we will now use a simple loop to get all the values one by one
for message in consumer:
    if message is not None:
        # add tweet text to the list for further analysis 
        input_text.append(message.value)
        
        print (message.offset, message.value)
        # set a condition to stop the consumer and the producer
        if len(input_text) == user_input:
            consumer.stop()
# Out:
# Please enter how many result to show: 10
# 0 b'["YENBO", "2022", "35.0", "Fall"]'
# 1 b'["YENBO", "2022", "35.0", "Fall"]'
# 2 b'["KING ABDULAZIZ INTL", "2022", "35.0", "Fall"]'
# 3 b'["WEJH", "2022", "35.0", "Fall"]'
# 4 b'["KING ABDULAZIZ INTL", "2022", "35.0", "Fall"]'
# 5 b'["YENBO", "2022", "35.0", "Fall"]'
# 6 b'["YENBO", "2022", "35.0", "Fall"]'
# 7 b'["YENBO", "2022", "35.0", "Fall"]'
# 8 b'["YENBO", "2022", "35.0", "Fall"]'
# 9 b'["JUBAIL", "2022", "35.0", "Fall"]'
# ---------------------------------------------------------------------------
# ConsumerStoppedException                  Traceback (most recent call last)
# /var/folders/tl/qz337dp93ll0vvq0cgprmr5c0000gn/T/ipykernel_1366/4204452519.py in <module>
#      21
#      22  #we will now use a simple loop to get all the values one by one
# ---> 23 for message in consumer:
#      24     if message is not None:
#      25         # add tweet text to the list for further analysis
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pykafka/simpleconsumer.py in __iter__(self)
#     459         """Yield an infinite stream of messages until the consumer times out"""
#     460         while True:
# --> 461             message = self.consume(block=True)
#     462             if not message:
#     463                 return
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pykafka/simpleconsumer.py in consume(self, block, unblock_event)
#     487                 # least one message is waiting in some queue.
#     488                 if not self._running:
# --> 489                     raise ConsumerStoppedException()
#     490                 message = None
#     491                 while not message:
#
# ConsumerStoppedException:
