# %% [markdown]
# ****
# ### >> Send to consumer Riyadh air temperature in year (2022). And just show the station name , year, air temperature and Season name columns
# ****

# %%
from kafka import KafkaAdminClient, KafkaConsumer, KafkaProducer
from kafka.admin import NewTopic
import json
from json import loads
import csv
from csv import DictReader

# Required setting for Kafka Producer
topicname = 'Riyadh_air_temperature'
producer = KafkaProducer(bootstrap_servers='localhost:9092',value_serializer=lambda v: binascii.hexlify(v.encode('utf-8')))
producer = KafkaProducer()


# iterate over each line as a ordered dictionary and print only few column by column name
with open('SaudiWeather.csv','r') as read_obj:
    csv_dict_reader = DictReader(read_obj,dialect=csv.excel)
    for column in csv_dict_reader:
        if column["station_name"] == 'RIYADH AB' and column["YEAR"] == '2022':
            ack = producer.send(topicname,json.dumps((column['station_name'], column['YEAR'],column['air_temperature'],column["Season_name"])).encode('utf-8'))
            metadata = ack.get()
            print(metadata.topic, metadata.partition)
# Out:
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# Riyadh_air_temperature 0
# ...
